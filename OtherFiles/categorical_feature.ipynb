# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# 설정
USE_SUBLABEL = False
URL_PER_SITE = 10
TOTAL_URLS_MON = 950  # Monitored 데이터 URL 수
TOTAL_URLS_UNMON = 3000  # Unmonitored 데이터 URL 수

# Number of Incoming/Outgoing Packets
def count_in_out_packets(data):
    num_incoming = sum(1 for c in data if c > 0)  # Positive indicates incoming
    num_outgoing = sum(1 for c in data if c < 0)  # Negative indicates outgoing
    return num_incoming, num_outgoing


# Number of Incoming/Outgoing Packets as a Fraction of Total
def fraction_in_out_packets(num_incoming, num_outgoing):
    total_packets = num_incoming + num_outgoing
    if total_packets == 0:  # To avoid division by zero
        return 0, 0
    fraction_incoming = num_incoming / total_packets
    fraction_outgoing = num_outgoing / total_packets
    return fraction_incoming, fraction_outgoing


# Standard Deviation of Outgoing Packet Ordering List
def std_dev_outgoing_packets(data):
    outgoing_sizes = [abs(c) * 512 for c in data if c < 0]  # Only outgoing packets
    if len(outgoing_sizes) > 1:
        return np.std(outgoing_sizes)
    return 0


# Sum of All Items in the Alternative Concentration Feature List
def sum_alternative_concentration(size_seq):
    return sum(size_seq)


# Average of the Outgoing and Total Number of Packets
def avg_outgoing_and_total_packets(num_incoming, num_outgoing):
    total_packets = num_incoming + num_outgoing
    if total_packets == 0:  # To avoid division by zero
        return 0
    avg = (num_outgoing + total_packets) / 2
    return avg


# Sum of Incoming, Outgoing, and Total Number of Packets
def sum_in_out_total_packets(num_incoming, num_outgoing):
    return num_incoming + num_outgoing


# Sum of Alternative Number of Packets per Second
def sum_packets_per_second(time_seq, size_seq):
    total_time = sum(time_seq)
    if total_time == 0:
        return 0
    total_packets = sum(size_seq)
    return total_packets / total_time

# Total Number of Packets
def total_packets(num_incoming, num_outgoing):
    return num_incoming + num_outgoing

# Google 드라이브 마운트
drive.mount('/content/drive')

# 파일 경로 설정 (드라이브에서 파일 경로 확인 필요)
mon_file = '/content/drive/MyDrive/mon_standard.pkl'
unmon_file = '/content/drive/MyDrive/unmon_standard10_3000.pkl'

# 데이터 로드
with open(mon_file, 'rb') as f:
    mon_data = pickle.load(f)
with open(unmon_file, 'rb') as f:
    unmon_data = pickle.load(f)

# Monitored 데이터 변환
X1_mon, X2_mon, X3_mon, X4_mon, X5_mon, X6_mon, X7_mon, X8_mon, X9_mon, y_mon = [], [], [], [], [], [], [], [], [], []

# For monitored data
for i in range(TOTAL_URLS_MON):
    if USE_SUBLABEL:
        label = i
    else:
        label = i // URL_PER_SITE

    for sample in mon_data[i]:
        size_seq = []
        time_seq = []
        cumulative_size = []  # To store the cumulative size
        burst_seq = []  # To store the burst sequence

        prev_size = 0  # To track the previous size for burst calculation
        cumulative_sum = 0  # To calculate cumulative size
        for c in sample:
            dr = 1 if c > 0 else -1
            time_seq.append(abs(c))
            size = dr * 512
            size_seq.append(size)

            # Calculate cumulative size
            cumulative_sum += size
            cumulative_size.append(cumulative_sum)

            # Calculate burst sequence
            if size != prev_size:  # If direction changes, consider it a burst
                burst_seq.append(size)
            else:
                burst_seq.append(0)  # No burst if size is the same as previous

            prev_size = size

        num_incoming, num_outgoing = count_in_out_packets(sample)
        fraction_incoming, fraction_outgoing = fraction_in_out_packets(num_incoming, num_outgoing)
        std_dev_outgoing = std_dev_outgoing_packets(sample)
        sum_alternative = sum_alternative_concentration(size_seq)
        avg_outgoing_total = avg_outgoing_and_total_packets(num_incoming, num_outgoing)
        sum_in_out_total = sum_in_out_total_packets(num_incoming, num_outgoing)
        sum_per_second = sum_packets_per_second(time_seq, size_seq)
        total = total_packets(num_incoming, num_outgoing)

        # Store all features in respective lists
        X1_mon.append(time_seq)
        X2_mon.append(size_seq)
        X3_mon.append(cumulative_size)
        X4_mon.append(burst_seq)
        X5_mon.append(fraction_incoming)
        X6_mon.append(fraction_outgoing)
        X7_mon.append(std_dev_outgoing)
        X8_mon.append(sum_alternative)
        X9_mon.append(avg_outgoing_total)
        y_mon.append(label)

X1_unmon, X2_unmon, X3_unmon, X4_unmon, X5_unmon, X6_unmon, X7_unmon, X8_unmon, X9_unmon = [], [], [], [], [], [], [], [], []

# For unmonitored data
for i in range(TOTAL_URLS_UNMON):
    size_seq = []
    time_seq = []
    cumulative_size = []  # To store the cumulative size
    burst_seq = []  # To store the burst sequence

    prev_size = 0  # To track the previous size for burst calculation
    cumulative_sum = 0  # To calculate cumulative size

    for c in unmon_data[i]:
        dr = 1 if c > 0 else -1
        time_seq.append(abs(c))
        size = dr * 512
        size_seq.append(size)

        # Calculate cumulative size
        cumulative_sum += size
        cumulative_size.append(cumulative_sum)

        # Calculate burst sequence
        if size != prev_size:  # If direction changes, consider it a burst
            burst_seq.append(size)
        else:
            burst_seq.append(0)  # No burst if size is the same as previous

        prev_size = size

    num_incoming, num_outgoing = count_in_out_packets(unmon_data[i])
    fraction_incoming, fraction_outgoing = fraction_in_out_packets(num_incoming, num_outgoing)
    std_dev_outgoing = std_dev_outgoing_packets(unmon_data[i])
    sum_alternative = sum_alternative_concentration(size_seq)
    avg_outgoing_total = avg_outgoing_and_total_packets(num_incoming, num_outgoing)
    sum_in_out_total = sum_in_out_total_packets(num_incoming, num_outgoing)
    sum_per_second = sum_packets_per_second(time_seq, size_seq)
    total = total_packets(num_incoming, num_outgoing)

    # Store all features in respective lists
    X1_unmon.append(time_seq)
    X2_unmon.append(size_seq)
    X3_unmon.append(cumulative_size)
    X4_unmon.append(burst_seq)
    X5_unmon.append(fraction_incoming)
    X6_unmon.append(fraction_outgoing)
    X7_unmon.append(std_dev_outgoing)
    X8_unmon.append(sum_alternative)
    X9_unmon.append(avg_outgoing_total)

# Monitored와 Unmonitored 데이터를 Pandas 데이터프레임으로 변환
mon_df = pd.DataFrame({
    'Fraction Incoming (X5)': X5_mon,
    'Fraction Outgoing (X6)': X6_mon,
    'Std Dev Outgoing (X7)': X7_mon,
    'Sum Alternative (X8)': X8_mon,
    'Average Outgoing & Total (X9)': X9_mon,
    'Label': ['Monitored'] * len(X5_mon)
})

unmon_df = pd.DataFrame({
    'Fraction Incoming (X5)': X5_unmon,
    'Fraction Outgoing (X6)': X6_unmon,
    'Std Dev Outgoing (X7)': X7_unmon,
    'Sum Alternative (X8)': X8_unmon,
    'Average Outgoing & Total (X9)': X9_unmon,
    'Label': ['Unmonitored'] * len(X5_unmon)
})

# 데이터 병합
data = pd.concat([mon_df, unmon_df], ignore_index=True)
print("데이터 로드 및 준비 완료!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 데이터 로드 및 준비 완료!

# %% [markdown]
# #1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# Time Sequence (X1) KDE + Boxplot
sns.kdeplot(data=pd.DataFrame({'Time Sequence': [value for sublist in X1_mon for value in sublist],
                               'Label': ['Monitored'] * sum(len(sublist) for sublist in X1_mon)}),
            x='Time Sequence', hue='Label', fill=True, common_norm=False, alpha=0.6)
sns.kdeplot(data=pd.DataFrame({'Time Sequence': [value for sublist in X1_unmon for value in sublist],
                               'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X1_unmon)}),
            x='Time Sequence', hue='Label', fill=True, common_norm=False, alpha=0.6)
plt.title("Time Sequence (X1) Distribution")
plt.xlabel("Time Sequence")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

sns.boxplot(data=pd.concat([pd.DataFrame({'Time Sequence': [value for sublist in X1_mon for value in sublist],
                                          'Label': ['Monitored'] * sum(len(sublist) for sublist in X1_mon)}),
                            pd.DataFrame({'Time Sequence': [value for sublist in X1_unmon for value in sublist],
                                          'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X1_unmon)})]),
            x='Label', y='Time Sequence')
plt.title("Time Sequence (X1) Boxplot")
plt.xlabel("Category")
plt.ylabel("Time Sequence")

plt.tight_layout()
plt.show()

# %% [markdown]
# #2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(data=pd.DataFrame({'Size Sequence': [value for sublist in X2_mon for value in sublist],
                                'Label': ['Monitored'] * sum(len(sublist) for sublist in X2_mon)}),
             x='Size Sequence', hue='Label', bins=30, kde=True, alpha=0.6)
sns.histplot(data=pd.DataFrame({'Size Sequence': [value for sublist in X2_unmon for value in sublist],
                                'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X2_unmon)}),
             x='Size Sequence', hue='Label', bins=30, kde=True, alpha=0.6)
plt.title("Size Sequence (X2) Distribution")
plt.xlabel("Size Sequence")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(data=pd.concat([pd.DataFrame({'Size Sequence': [value for sublist in X2_mon for value in sublist],
                                          'Label': ['Monitored'] * sum(len(sublist) for sublist in X2_mon)}),
                            pd.DataFrame({'Size Sequence': [value for sublist in X2_unmon for value in sublist],
                                          'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X2_unmon)})]),
            x='Label', y='Size Sequence')
plt.title("Size Sequence (X2) Boxplot")
plt.xlabel("Category")
plt.ylabel("Size Sequence")

plt.tight_layout()
plt.show()

# %% [markdown]
# #3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# X3 데이터 생성
x3_data = pd.concat([
    pd.DataFrame({
        'Cumulative Size': [value for sublist in X3_mon for value in sublist],
        'Label': ['Monitored'] * sum(len(sublist) for sublist in X3_mon)
    }),
    pd.DataFrame({
        'Cumulative Size': [value for sublist in X3_unmon for value in sublist],
        'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X3_unmon)
    })
], ignore_index=True)

# KDE Plot (밀도 그래프)
sns.kdeplot(data=x3_data, x='Cumulative Size', hue='Label', fill=True, common_norm=False, alpha=0.6)
plt.title("Cumulative Size (X3) Distribution")
plt.xlabel("Cumulative Size")
plt.ylabel("Density")

# Boxplot (박스플롯)
sns.boxplot(data=x3_data, x='Label', y='Cumulative Size')
plt.title("Cumulative Size (X3) Boxplot")
plt.xlabel("Category")
plt.ylabel("Cumulative Size")

plt.tight_layout()
plt.show()

# %% [markdown]
# #4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(data=pd.DataFrame({'Burst Sequence': [value for sublist in X4_mon for value in sublist],
                                'Label': ['Monitored'] * sum(len(sublist) for sublist in X4_mon)}),
             x='Burst Sequence', hue='Label', bins=30, kde=True, alpha=0.6)
sns.histplot(data=pd.DataFrame({'Burst Sequence': [value for sublist in X4_unmon for value in sublist],
                                'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X4_unmon)}),
             x='Burst Sequence', hue='Label', bins=30, kde=True, alpha=0.6)
plt.title("Burst Sequence (X4) Distribution")
plt.xlabel("Burst Sequence")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(data=pd.concat([pd.DataFrame({'Burst Sequence': [value for sublist in X4_mon for value in sublist],
                                          'Label': ['Monitored'] * sum(len(sublist) for sublist in X4_mon)}),
                            pd.DataFrame({'Burst Sequence': [value for sublist in X4_unmon for value in sublist],
                                          'Label': ['Unmonitored'] * sum(len(sublist) for sublist in X4_unmon)})]),
            x='Label', y='Burst Sequence')
plt.title("Burst Sequence (X4) Boxplot")
plt.xlabel("Category")
plt.ylabel("Burst Sequence")

plt.tight_layout()
plt.show()

# %% [markdown]
# #5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.kdeplot(data=data, x='Fraction Incoming (X5)', hue='Label', fill=True, common_norm=False, alpha=0.6)
plt.title("Fraction Incoming (X5) Distribution")
plt.xlabel("Fraction Incoming")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# #6

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.kdeplot(data=data, x='Fraction Outgoing (X6)', hue='Label', fill=True, common_norm=False, alpha=0.6)
plt.title("Fraction Outgoing (X6) Distribution")
plt.xlabel("Fraction Outgoing")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# #7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Label', y='Std Dev Outgoing (X7)')
plt.title("Std Dev Outgoing (X7) Boxplot")
plt.xlabel("Category")
plt.ylabel("Std Dev Outgoing")

plt.tight_layout()
plt.show()

# %% [markdown]
# #8

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn 스타일 설정
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# Sum Alternative (X8) KDE 플롯
sns.kdeplot(data=mon_df, x='Sum Alternative (X8)', hue='Label', fill=True, common_norm=False, alpha=0.6, label='Monitored')
sns.kdeplot(data=unmon_df, x='Sum Alternative (X8)', hue='Label', fill=True, common_norm=False, alpha=0.6, label='Unmonitored')

# 그래프 제목 및 축 레이블 설정
plt.title("Sum Alternative (X8) Distribution")
plt.xlabel("Sum Alternative (X8)")
plt.ylabel("Density")
plt.legend(title="Category")
plt.tight_layout()

# 그래프 표시
plt.show()

# %% [markdown]
# #9

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

plt.subplot(4, 3, 10)
sns.kdeplot(data=data, x='Average Outgoing & Total (X9)', hue='Label', fill=True, common_norm=False, alpha=0.6)
plt.title("Average Outgoing & Total (X9) Distribution")
plt.xlabel("Average Outgoing & Total")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# #Random Forest Model

# %%
# 필요한 라이브러리 임포트
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Step 1: 특징 데이터 준비
# X5 ~ X9 특징 데이터프레임 생성
mon_features = pd.DataFrame({
    'Fraction Incoming (X5)': X5_mon,
    'Fraction Outgoing (X6)': X6_mon,
    'Std Dev Outgoing (X7)': X7_mon,
    'Sum Alternative (X8)': X8_mon,
    'Average Outgoing & Total (X9)': X9_mon,
})

# y_mon을 그대로 레이블로 사용
mon_features['Label'] = y_mon  # y_mon에는 이미 19000개의 레이블이 존재

# Step 2: 학습 데이터와 레이블 분리
X = mon_features.drop('Label', axis=1)  # 특징 데이터
y = mon_features['Label']  # 레이블 데이터

# Step 3: 데이터 분할 (학습 데이터와 테스트 데이터)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 4: 랜덤포레스트 모델 생성 및 학습
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # 100개의 트리
rf_model.fit(X_train, y_train)  # 모델 학습

# Step 5: 테스트 데이터로 예측
y_pred = rf_model.predict(X_test)

# Step 6: 정확도 및 분류 성능 출력
accuracy = accuracy_score(y_test, y_pred)
print(f"랜덤포레스트 모델 정확도: {accuracy:.2f}")
print("\n분류 보고서:")
print(classification_report(y_test, y_pred))

# Step 7: 특징 중요도 시각화
feature_importances = rf_model.feature_importances_
features = X.columns

plt.figure(figsize=(10, 6))
plt.bar(features, feature_importances, color='skyblue')
plt.title("Feature Importances in Random Forest")
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.xticks(rotation=45)
plt.show()
# Out:
# 랜덤포레스트 모델 정확도: 0.53
#
# 분류 보고서:
#               precision    recall  f1-score   support
#
#            0       0.39      0.34      0.36        62
#            1       0.32      0.25      0.28        59
#            2       0.57      0.78      0.66        55
#            3       0.40      0.59      0.48        46
#            4       0.56      0.58      0.57        53
#            5       0.69      0.65      0.67        63
#            6       0.71      0.82      0.76        65
#            7       0.60      0.48      0.53        64
#            8       0.61      0.56      0.58        59
#            9       0.36      0.60      0.45        47
#           10       0.60      0.52      0.55        66
#           11       0.60      0.53      0.56        57
#           12       0.77      0.86      0.82        59
#           13       0.28      0.26      0.27        54
#           14       0.50      0.34      0.41        58
#           15       0.59      0.69      0.64        59
#           16       0.64      0.64      0.64        55
#           17       0.45      0.43      0.44        67
#           18       0.65      0.82      0.73        55
#           19       0.34      0.36      0.35        55
#           20       0.87      0.90      0.88        68
#           21       0.31      0.21      0.25        58
#           22       0.28      0.29      0.29        55
#           23       0.65      0.71      0.68        58
#           24       0.23      0.17      0.19        66
#           25       0.65      0.54      0.59        63
#           26       0.62      0.76      0.68        54
#           27       0.44      0.43      0.44        60
#           28       0.67      0.62      0.64        55
#           29       0.51      0.59      0.55        64
#           30       0.71      0.66      0.68        62
#           31       0.55      0.63      0.59        54
#           32       0.42      0.38      0.40        65
#           33       0.51      0.70      0.59        53
#           34       0.27      0.20      0.23        64
#           35       0.52      0.64      0.58        56
#           36       0.30      0.33      0.32        54
#           37       0.41      0.35      0.38        71
#           38       0.45      0.41      0.43        70
#           39       0.43      0.36      0.39        66
#           40       0.44      0.36      0.39        67
#           41       0.65      0.68      0.67        63
#           42       0.34      0.39      0.36        56
#           43       0.63      0.79      0.70        53
#           44       0.88      0.90      0.89        62
#           45       0.34      0.36      0.35        55
#           46       0.46      0.51      0.48        55
#           47       0.41      0.34      0.37        59
#           48       0.48      0.52      0.50        58
#           49       0.65      0.53      0.59        64
#           50       0.45      0.46      0.46        50
#           51       0.39      0.47      0.43        60
#           52       0.62      0.58      0.60        66
#           53       0.43      0.47      0.45        49
#           54       0.66      0.64      0.65        70
#           55       0.38      0.45      0.41        49
#           56       0.83      0.87      0.85        63
#           57       0.48      0.41      0.44        58
#           58       0.68      0.72      0.70        57
#           59       0.49      0.62      0.55        64
#           60       0.55      0.67      0.60        57
#           61       0.43      0.41      0.42        79
#           62       0.60      0.53      0.56        75
#           63       0.30      0.30      0.30        47
#           64       0.59      0.63      0.61        63
#           65       0.45      0.51      0.48        53
#           66       0.56      0.57      0.57        68
#           67       0.62      0.67      0.64        58
#           68       0.57      0.43      0.49        70
#           69       0.40      0.35      0.37        66
#           70       0.92      0.95      0.94        62
#           71       0.35      0.30      0.32        57
#           72       0.42      0.44      0.43        63
#           73       0.65      0.68      0.67        63
#           74       0.40      0.33      0.36        73
#           75       0.79      0.88      0.83        59
#           76       0.88      0.93      0.90        60
#           77       0.34      0.27      0.30        51
#           78       0.15      0.11      0.13        61
#           79       0.37      0.36      0.36        59
#           80       0.81      0.67      0.73        66
#           81       0.35      0.42      0.38        62
#           82       0.60      0.48      0.53        69
#           83       0.43      0.55      0.48        53
#           84       0.45      0.40      0.42        68
#           85       0.70      0.66      0.68        71
#           86       0.93      0.96      0.94        53
#           87       0.56      0.44      0.49        55
#           88       0.47      0.55      0.50        55
#           89       0.44      0.49      0.46        55
#           90       0.37      0.32      0.34        56
#           91       0.53      0.52      0.53        63
#           92       0.41      0.40      0.40        55
#           93       0.67      0.72      0.69        58
#           94       0.41      0.35      0.38        65
#
#     accuracy                           0.53      5700
#    macro avg       0.52      0.53      0.52      5700
# weighted avg       0.53      0.53      0.52      5700

# %% [markdown]
# #SVM_OPENWORLD

# %%
# Features(X1 ~ X9)와 Labels 준비
X = data[['Fraction Incoming (X5)', 'Fraction Outgoing (X6)', 'Std Dev Outgoing (X7)',
          'Sum Alternative (X8)', 'Average Outgoing & Total (X9)']].values
y = data['Label'].apply(lambda x: 1 if x == 'Monitored' else -1).values  # Monitored: 1, Unmonitored: -1

# 데이터 분할: 학습용과 테스트용
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Feature Scaling (SVM 모델에선 중요한 단계)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# SVM 모델 학습
svm_model = SVC(kernel='linear', random_state=42)  # Linear kernel
svm_model.fit(X_train_scaled, y_train)

# 예측
y_pred = svm_model.predict(X_test_scaled)

# 정확도 계산
accuracy = accuracy_score(y_test, y_pred)
print(f"모델 정확도: {accuracy * 100:.2f}%")

# 그래프 시각화
plt.figure(figsize=(10, 6))

# SVM 분류 경계 시각화: 두 특성을 사용한 2D 그래프
plt.scatter(X_test_scaled[:, 0], X_test_scaled[:, 1], c=y_pred, cmap='coolwarm', edgecolors='k', s=50, alpha=0.6)
plt.scatter(X_test_scaled[:, 0], X_test_scaled[:, 1], c=y_test, cmap='coolwarm', marker='x', s=100, alpha=0.9)

plt.title("SVM Classifier - Monitored vs Unmonitored Web Traffic")
plt.xlabel('Fraction Incoming (X5)')
plt.ylabel('Fraction Outgoing (X6)')
plt.legend(["Predicted", "True"], loc="best")
plt.show()
# Out:
# 모델 정확도: 86.64%

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# 혼동 행렬
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# 분류 성능 리포트 (Precision, Recall, F1-Score)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, svm_model.decision_function(X_test_scaled))
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[   0  882]
#  [   0 5718]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       882
#            1       0.87      1.00      0.93      5718
#
#     accuracy                           0.87      6600
#    macro avg       0.43      0.50      0.46      6600
# weighted avg       0.75      0.87      0.80      6600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
